# %%
import mule
import xarray as xr
import os

# %%
ancilFilename = '/scratch/public/dm5220/tilo/co2'

# %%
netcdfOrig = '/scratch/public/dm5220/tilo/orig_co2.nc'
d = xr.open_dataset(netcdfOrig)
netcdfFilename = '/scratch/public/dm5220/tilo/co2.nc'
d.co2emiss.isel(time=slice(0,12)).to_netcdf(netcdfFilename)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/xarray/backends/file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/scratch/public/dm5220/tilo/orig_co2.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), '41be5d47-4657-4fb0-9ad6-47e0e17945dd']
#
# ...

# %%
os.system('cd /g/data/p66/txz599/ACCESS-ESM_tools/ancil')
os.system('pwd')
# Out:
# /g/data/p66/txz599/ACCESS-ESM_tools/ancil
# 0

# %%
ancilFilename = 'co2'

# Get netcdf data
netcdfFilename = 'co2.nc'
netcdfFile = xr.open_dataset(netcdfFilename)
data=netcdfFile.co2emiss

# %%
# Get netcdf data
netcdfFilename = 'CO2_fluxes_ESM_1750.nc'
netcdfFile = xr.open_dataset(netcdfFilename)
data=netcdfFile.field1561

# %%
data
# Out:
# <xarray.DataArray 'field1561' (t: 12, surface: 1, latitude: 145, longitude: 192)>
# [334080 values with dtype=float32]
# Coordinates:
#   * t          (t) datetime64[ns] 1750-01-15 1750-02-15 ... 1750-12-15
#   * longitude  (longitude) float32 0.0 1.875 3.75 5.625 ... 354.4 356.2 358.1
#   * latitude   (latitude) float32 -90.0 -88.75 -87.5 -86.25 ... 87.5 88.75 90.0
#   * surface    (surface) float32 0.0
# Attributes:
#     long_name:  CO2 SURFACE EMISSIONS      KG/M**2/S
#     units:      kg m-2 s-1
#     source:     No field processing
#     name:       field1561
#     title:      CO2 SURFACE EMISSIONS      KG/M**2/S
#     date:       01/01/50
#     time:       00:00

# %%
ancilFile = mule.load_umfile(ancilFilename)
ancilFile.fields = [ancilFile.fields[0]]
ancilFile.fixed_length_header.time_type = 0
ancilFile.fields[0].set_data_provider(mule.ArrayDataProvider(data))
ancilFile.to_file(f'{ancilFilename}_test')
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/mule/stashmaster.py:284: UserWarning: Ancillary files do not define the UM version number in the Fixed Length Header. No STASHmaster file loaded: Fields will not have STASH entries attached.
#   warnings.warn(msg)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 4
#       2 ancilFile.fields = [ancilFile.fields[0]]
#       3 ancilFile.fixed_length_header.time_type = 0
# ----> 4 ancilFile.fields[0].set_data_provider(mule.ArrayDataProvider(data))
#       5 ancilFile.to_file(f'{ancilFilename}_test')
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/mule/__init__.py:824, in ArrayDataProvider.__init__(self, array)
#     822 if len(shape) != 2:
#     823     msg = 'ArrayDataProvider has shape {}, which is not 2-dimensional.'
# ...

# %%
mule.
